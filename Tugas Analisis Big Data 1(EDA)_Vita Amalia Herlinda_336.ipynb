# %% [markdown]
# # **Dataset OULAD**
#
# * Nama  : Vita Amalia Herlinda
# * Kelas : Analisis Big Data D
#
# Open University Learning Analytics Dataset (OULAD) adalah kumpulan data yang berisi data tentang mata kuliah(courses), mahasiswa(student), dan interaksinya dengan Virtual Learning Environment (VLE).
#
# Kumpulan data ini unik karena berisi data demografi bersama dengan kumpulan data aliran klik interaksi siswa di VLE, ​​sehingga memungkinkan analisis perilaku siswa yang diwakili oleh tindakan mereka. Kumpulan data terdiri dari tabel yang dihubungkan menggunakan pengidentifikasi unik dan disimpan dalam beberapa file CSV.Kumpulan data tersedia secara gratis di bawah lisensi .

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **EDA**
# * Student Assessment

# %% [markdown]
# Digunakan untuk membaca file CSV ke objek Pandas DataFrame dan menampilkan 5 baris pertama pada dataframe

# %%
studentAssessment = pd.read_csv('/content/drive/MyDrive/studentAssessment.csv')

studentAssessment.head(5)
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %% [markdown]
# Melihat jumlah baris dan kolom pada dataset student assessment

# %%
studentAssessment.shape
# Out:
# (173912, 5)

# %% [markdown]
# Berguna untuk memahami distribusi nilai di setiap kolom dan untuk mengidentifikasi potensi masalah pada data, seperti nilai yang hilang atau terduplikasi

# %%
studentAssessment.nunique()
# Out:
# id_assessment       188
# id_student        23369
# date_submitted      312
# is_banked             2
# score               101
# dtype: int64

# %% [markdown]
# Memberikan informasi tentang DataFrame, termasuk jumlah nilai bukan nol, tipe data setiap kolom, dan penggunaan memori DataFrame. dan juga tipe data yang hilang atau salah.

# %%
studentAssessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB

# %% [markdown]
# Digunakan untuk menghitung jumlah nilai yang hilang di setiap kolom objek DataFrame yang dibuat dari file CSV

# %%
studentAssessment.isnull().sum()
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %% [markdown]
# Digunakan untuk menghasilkan statistik deskriptif objek DataFrame yang dibuat dari file CSV

# %%
studentAssessment.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173912.000000
# mean       75.799573
# std        18.788755
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %% [markdown]
# # EDA
# ### StudentInfo
# * Pada tahapan ini digunakan untuk membaca file csv ke dalam dataframe dan di tampilkan 5 baris pertama

# %%
studentInfo = pd.read_csv('/content/drive/MyDrive/studentInfo.csv')

studentInfo.head(5)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %% [markdown]
# shape berfungsi untuk melihat jumlah baris dan kolom yang ada pada dataset studentInfo

# %%
studentInfo.shape
# Out:
# (32593, 12)

# %% [markdown]
# nunique ini berfungsi melihat nilai disetiap kolom yang bermasalah,hilang atau terduplikasi pada data.

# %%
studentInfo.nunique()
# Out:
# code_module                 7
# code_presentation           4
# id_student              28785
# gender                      2
# region                     13
# highest_education           5
# imd_band                   10
# age_band                    3
# num_of_prev_attempts        7
# studied_credits            61
# disability                  2
# final_result                4
# dtype: int64

# %% [markdown]
# info digunakan untuk melihat rangkuman dari nama kolom, type data atau segalah hal yang berkaitan dengan dataframe

# %%
studentInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %% [markdown]
# describe ini digunakan untuk melihat hasil statistik deskriptif dari dataframe.

# %%
studentInfo.describe()
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.259300e+04          32593.000000     32593.000000
# mean   7.066877e+05              0.163225        79.758691
# std    5.491673e+05              0.479758        41.071900
# min    3.733000e+03              0.000000        30.000000
# 25%    5.085730e+05              0.000000        60.000000
# 50%    5.903100e+05              0.000000        60.000000
# 75%    6.444530e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000

# %% [markdown]
# isnull.sum digunakan melihat dan menghitung jumlah missing value pada setiap baris data di setiap kolom.

# %%
studentInfo.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %% [markdown]
# # EDA
# * StudentRegristration

# %% [markdown]
# read_csv digunakan untuk membaca dataframe studentRegristration dan menampilkan 5 baris pertama pada dataset.

# %%
StudentRegristration= pd.read_csv('/content/drive/MyDrive/studentRegistration.csv')

StudentRegristration.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %% [markdown]
# untuk melihat jumlah baris dan kolom pada studentregristration.

# %%
StudentRegristration.shape
# Out:
# (32593, 5)

# %% [markdown]
# untuk melihat type data dari setiap kolom

# %%
StudentRegristration.dtypes
# Out:
# code_module             object
# code_presentation       object
# id_student               int64
# date_registration      float64
# date_unregistration    float64
# dtype: object

# %% [markdown]
# Melihat masalah pada data seperti nilai yang hilang dan terduplikasi.

# %%
StudentRegristration.nunique()
# Out:
# code_module                7
# code_presentation          4
# id_student             28785
# date_registration        332
# date_unregistration      416
# dtype: int64

# %% [markdown]
# melihat informasi mengenai dataframe mulai dari type data,nama kolom dan memory yang digunakan.

# %%
StudentRegristration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# mengecek apakah terdapat missing value pada setiap baris yang ada pada data

# %%
StudentRegristration.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %% [markdown]
# melihat statistik deskriptif dari data studentregristration

# %%
StudentRegristration.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %% [markdown]
# # EDA
# ### vle
# * membaca data dan menmapilkan 5 baris pertama data.

# %%
vle= pd.read_csv('/content/drive/MyDrive/vle.csv')

vle.head(5)
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %% [markdown]
# melihat jumlah baris dan kolom pada data

# %%
vle.shape
# Out:
# (6364, 6)

# %% [markdown]
# melihat informasi yang ada pada dataframe seperti nama kolom, dan type data

# %%
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB

# %% [markdown]
# melihat tipe data setiap kolom saja.

# %%
vle.dtypes
# Out:
# id_site                int64
# code_module           object
# code_presentation     object
# activity_type         object
# week_from            float64
# week_to              float64
# dtype: object

# %% [markdown]
# mengecek apakah dalam data terdapat nilai yang hilang atau terduplikasi

# %%
vle.nunique()
# Out:
# id_site              6364
# code_module             7
# code_presentation       4
# activity_type          20
# week_from              30
# week_to                30
# dtype: int64

# %% [markdown]
# mengecek apakah setiap baris pada kolom terdapat missing value

# %%
vle.isnull().sum()
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %% [markdown]
# untuk statistik deskriptif

# %%
vle.describe()
# Out:
#             id_site    week_from      week_to
# count  6.364000e+03  1121.000000  1121.000000
# mean   7.260991e+05    15.204282    15.214987
# std    1.283151e+05     8.792865     8.779806
# min    5.267210e+05     0.000000     0.000000
# 25%    6.615928e+05     8.000000     8.000000
# 50%    7.300965e+05    15.000000    15.000000
# 75%    8.140162e+05    22.000000    22.000000
# max    1.077905e+06    29.000000    29.000000

# %% [markdown]
# # EDA
# * Course

# %% [markdown]
# Membaca dataframe file csv dan menampilkan 5 data

# %%
course= pd.read_csv('/content/drive/MyDrive/courses.csv')

# %%
course.head(5)
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %% [markdown]
# informasi mengenai jumlah baris dan kolom pada dataset

# %%
course.shape
# Out:
# (22, 3)

# %% [markdown]
# melihat informasi dataframe

# %%
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes

# %% [markdown]
# melihat type data pada setiap kolom data.

# %%
course.dtypes
# Out:
# code_module                   object
# code_presentation             object
# module_presentation_length     int64
# dtype: object

# %% [markdown]
# melihat nilai yang terduplikasih

# %%
course.nunique()
# Out:
# code_module                   7
# code_presentation             4
# module_presentation_length    7
# dtype: int64

# %% [markdown]
# mengecek missing value pada setiap baris yang ada di setiap kolom data

# %%
course.isnull().sum()
# Out:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %% [markdown]
# untuk melihat statistik deskriptif

# %%
course.describe
# Out:
# <bound method NDFrame.describe of    code_module code_presentation  module_presentation_length
# 0          AAA             2013J                         268
# 1          AAA             2014J                         269
# 2          BBB             2013J                         268
# 3          BBB             2014J                         262
# 4          BBB             2013B                         240
# 5          BBB             2014B                         234
# 6          CCC             2014J                         269
# 7          CCC             2014B                         241
# 8          DDD             2013J                         261
# 9          DDD             2014J                         262
# 10         DDD             2013B                         240
# 11         DDD             2014B                         241
# 12         EEE             2013J                         268
# 13         EEE             2014J                         269
# ...

# %% [markdown]
# # EDA
# * Assessment

# %% [markdown]
# membaca data dan menampilkan 5 data teratas

# %%
assessment=pd.read_csv('/content/drive/MyDrive/assessments.csv')

# %%
assessment.head(5)
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %% [markdown]
# melihat jumlah baris dan kolom data

# %%
assessment.shape
# Out:
# (206, 6)

# %% [markdown]
# melihat segala informasi mengenai dataframe yaitu jumlah kolom, type data, jumlah baris.

# %%
assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# ini digunakan hanya untuk melihat ype data yang ada pada setiap kolom.

# %%
assessment.dtypes
# Out:
# code_module           object
# code_presentation     object
# id_assessment          int64
# assessment_type       object
# date                 float64
# weight               float64
# dtype: object

# %% [markdown]
# mengecek nilai terduplikasi pada data

# %%
assessment.nunique()
# Out:
# code_module            7
# code_presentation      4
# id_assessment        206
# assessment_type        3
# date                  74
# weight                24
# dtype: int64

# %% [markdown]
# mengecek missing value pada data

# %%
assessment.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %% [markdown]
# untuk melihat statistik deskiptif

# %%
assessment.describe()
# Out:
#        id_assessment        date      weight
# count     206.000000  195.000000  206.000000
# mean    26473.975728  145.005128   20.873786
# std     10098.625521   76.001119   30.384224
# min      1752.000000   12.000000    0.000000
# 25%     15023.250000   71.000000    0.000000
# 50%     25364.500000  152.000000   12.500000
# 75%     34891.750000  222.000000   24.250000
# max     40088.000000  261.000000  100.000000

# %% [markdown]
# # EDA
# * studentVle

# %% [markdown]
# Membaca file csv studentvle dan menampilkan 5 baris teratas dari data.

# %%
studentvle= pd.read_csv('/content/drive/MyDrive/studentVle.csv')

# %%
studentvle.head(5)
# Out:
#   code_module code_presentation  id_student   id_site  date  sum_click
# 0         AAA             2013J     28400.0  546652.0 -10.0        4.0
# 1         AAA             2013J     28400.0  546652.0 -10.0        1.0
# 2         AAA             2013J     28400.0  546652.0 -10.0        1.0
# 3         AAA             2013J     28400.0  546614.0 -10.0       11.0
# 4         AAA             2013J     28400.0  546714.0 -10.0        1.0

# %% [markdown]
# melihat jumlah baris dan kolom pada data

# %%
studentvle.shape
# Out:
# (8769470, 6)

# %% [markdown]
# melihat informasi dataframe

# %%
studentvle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8769470 entries, 0 to 8769469
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         float64
#  3   id_site            float64
#  4   date               float64
#  5   sum_click          float64
# dtypes: float64(4), object(2)
# memory usage: 401.4+ MB

# %% [markdown]
# melihat type data dari setiap kolom data

# %%
studentvle.dtypes
# Out:
# code_module           object
# code_presentation     object
# id_student           float64
# id_site              float64
# date                 float64
# sum_click            float64
# dtype: object

# %% [markdown]
# melihat nilai yang duplikasi atau hilang

# %%
studentvle.nunique()
# Out:
# code_module              6
# code_presentation        4
# id_student           21953
# id_site               5276
# date                   295
# sum_click              466
# dtype: int64

# %% [markdown]
# melihat missing value pada setiap baris data

# %%
studentvle.isnull().sum()
# Out:
# code_module          0
# code_presentation    1
# id_student           1
# id_site              1
# date                 1
# sum_click            1
# dtype: int64

# %% [markdown]
# Deskripsi statistik data

# %%
studentvle.describe()
# Out:
#          id_student       id_site          date     sum_click
# count  8.769469e+06  8.769469e+06  8.769469e+06  8.769469e+06
# mean   7.342441e+05  7.150563e+05  9.115164e+01  3.599733e+00
# std    5.984047e+05  1.298297e+05  7.536850e+01  8.725960e+00
# min    6.516000e+03  5.267210e+05 -2.500000e+01  1.000000e+00
# 25%    4.978550e+05  5.510120e+05  2.300000e+01  1.000000e+00
# 50%    5.775260e+05  7.166380e+05  7.600000e+01  2.000000e+00
# 75%    6.328770e+05  8.137010e+05  1.510000e+02  3.000000e+00
# max    2.698588e+06  1.049562e+06  2.690000e+02  6.977000e+03
